# %%
from netCDF4 import Dataset
from netCDFfunc.utility import show_img

# %%
navo = Dataset(f'/Volumes/T7/NAVO_K10_SST_GDS2/2018/20181001000000-NAVO-L4HR1m-GLOB_GHRSST-K10_SST-v02.0-fv01.0.nc', 'r', format='NETCDF4')
show_img(navo['mask'][:].data[0])

# %%
avh = Dataset(f'/Volumes/T7/AVHRR_OI_SST/v2.1/2018/20181001120000-NCEI-L4_GHRSST-SSTblend-AVHRR_OI-GLOB-v02.0-fv02.1.nc', 'r', format='NETCDF4')
show_img(avh['mask'][:].data[0])

# %%
gammssa = Dataset(f'/Volumes/T7/GAMSSA_GDS2/2018/20181001120000-ABOM-L4_GHRSST-SSTfnd-GAMSSA_28km-GLOB-v02.0-fv01.0.nc', 'r', format='NETCDF4')
show_img(gammssa['mask'][:].data[0])

# %%
cmc = Dataset(f'/Volumes/T7/CMC/deg0.1/2018/20181001120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc', 'r', format='NETCDF4')
show_img(cmc['mask'][:].data[0])

# %%
cmc = Dataset(f'/Volumes/T7/CMC/deg0.1/2017/20171001120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc', 'r', format='NETCDF4')
show_img(cmc['analysed_sst'][:].data[0])

# %%
cmc['analysed_sst'][:].data[0]
# Out:
# array([[271.35, 271.35, 271.35, ..., 271.35, 271.35, 271.35],
#        [271.35, 271.35, 271.35, ..., 271.35, 271.35, 271.35],
#        [271.35, 271.35, 271.35, ..., 271.35, 271.35, 271.35],
#        ...,
#        [271.35, 271.35, 271.35, ..., 271.35, 271.35, 271.35],
#        [271.35, 271.35, 271.35, ..., 271.35, 271.35, 271.35],
#        [271.35, 271.35, 271.35, ..., 271.35, 271.35, 271.35]],
#       dtype=float32)

# %%
gammssa = Dataset(f'/Volumes/T7/GAMSSA_GDS2/2018/20181001120000-ABOM-L4_GHRSST-SSTfnd-GAMSSA_28km-GLOB-v02.0-fv01.0.nc', 'r', format='NETCDF4')
show_img(gammssa['analysed_sst'][:].mask[0])

# %%
gammssa = Dataset(f'/Volumes/T7/GAMSSA_GDS2/2013/20131001120000-ABOM-L4_GHRSST-SSTfnd-GAMSSA_28km-GLOB-v02.0-fv01.0.nc', 'r', format='NETCDF4')
show_img(gammssa['analysed_sst'][:].mask[0])

# %%
gammssa['analysed_sst'][:].mask
# Out:
# array([[[ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         ...,
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False]]])
