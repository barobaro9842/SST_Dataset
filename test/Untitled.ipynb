# %%
from netCDF4 import Dataset
from netCDFfunc.utility import *

# %%
grade = Dataset('/Volumes/T7/output_data/MW/nc/grade/2022/20220814120000-REMSS-L4_GHRSST-SSTfnd-MW_OI-GLOB-v02.0-fv05.0.nc_rok_grade.nc', 'r', format='NETCDF4')

# %%
np.unique(grade['grade'][:].data[0])
# Out:
# array([ 0.,  1.,  2.,  3.,  4.,  5., 10., nan], dtype=float32)

# %%
to_img(grade['grade'][:].data[0], show_img=True, is_grade=True)
