# %%
from netCDF4 import Dataset
from netCDFfunc.utility import *

# %%
d = Dataset('/Volumes/T7/output_data/test.nc', 'r', format='NETCDF4')

# %%
d
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     title: ROK 30 years(1991~2020) base SST anomaly data (20220817)
#     grid: 0.25
#     institution: NIA
#     name_creator: BNT
#     date_creation: 2022-08-23 15:13:29
#     comment: Average SST calculated 1991/1/1~2020/12/31
#     dimensions(sizes): ntime(1), nlat(132), nlon(160)
#     variables(dimensions): int16 time(ntime), float32 lat(nlat), float32 lon(nlon), float32 anomalysst(ntime, nlat, nlon)
#     groups:

# %%
to_img(d.variables['anomalysst'][:].data[0], show_img=True, is_anomaly=True)
