# %%
from netCDFfunc.preprocessing import get_data_A
from netCDFfunc.utility import check_err_mask_A

from tqdm.notebook import tqdm
from collections import Counter
import numpy as np

# %%
get_data_A(2016,1,1,'sst', is_mask=True).shape
# Out:
# (720, 1440)

# %%
for a,b in zip(get_data_A(2016,1,1,'sst', is_mask=True), get_data_A(2015,1,1,'sst', is_mask=True)):
    print(a,b)
# Out:
# [ True  True  True ...  True  True  True] [ True  True  True ...  True  True  True]
# [ True  True  True ...  True  True  True] [ True  True  True ...  True  True  True]
# [ True  True  True ...  True  True  True] [ True  True  True ...  True  True  True]
# [ True  True  True ...  True  True  True] [ True  True  True ...  True  True  True]
# [ True  True  True ...  True  True  True] [ True  True  True ...  True  True  True]
# [ True  True  True ...  True  True  True] [ True  True  True ...  True  True  True]
# [ True  True  True ...  True  True  True] [ True  True  True ...  True  True  True]
# [ True  True  True ...  True  True  True] [ True  True  True ...  True  True  True]
# [ True  True  True ...  True  True  True] [ True  True  True ...  True  True  True]
# [ True  True  True ...  True  True  True] [ True  True  True ...  True  True  True]
# [ True  True  True ...  True  True  True] [ True  True  True ...  True  True  True]
# ...

# %%
check_err_mask_A('err')
# Out:
#   0%|          | 0/41 [00:00<?, ?it/s]
# (0, [])

# %%
for a,b in zip(get_data_A(2016,1,1,'lon'), get_data_A(2015,1,1,'lon')):
    print(a,b)
