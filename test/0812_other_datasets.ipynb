# %%
from netCDF4 import Dataset
import numpy as np
import datetime as dt
import os

from netCDFfunc.utility import to_img

# %%
year = 2016
month = 1
day = 1

# %%
date = dt.date(year,month,day).strftime('%Y%m%d')
ds_in = Dataset(f"/Volumes/T7/CMC/deg0.1/2016/{date}120000-CMC-L4_GHRSST-SSTfnd-CMC0.1deg-GLOB-v02.0-fv03.0.nc")

# %%
to_img(ds_in.variables['analysed_sst'][:].data[0], show_img=True, is_anomaly=True)
